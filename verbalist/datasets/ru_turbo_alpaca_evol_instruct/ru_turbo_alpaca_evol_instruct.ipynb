# %%
from datasets import load_dataset
dataset = load_dataset("IlyaGusev/ru_turbo_alpaca_evol_instruct")
dataset['train'][0]
# Out:
# ...
# No config specified, defaulting to: ru_turbo_alpaca_evol_instruct/default
# ...
# Generating train split:   0%|          | 0/47793 [00:00<?, ? examples/s]
# Dataset ru_turbo_alpaca_evol_instruct downloaded and prepared to /home/kosenko/.cache/huggingface/datasets/IlyaGusev___ru_turbo_alpaca_evol_instruct/default/0.0.1/a4a2dd8f35b048a09a2bb1580edafa75f478b05f88d04e5500c9fc1038ebc063. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
dataset['train'].push_to_hub('dim/ru_turbo_alpaca_evol_instruct', private=True)
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/48 [00:00<?, ?ba/s]

# %%
dataset = dataset['train'].train_test_split(test_size=3000, seed=42)
dataset = dataset['test']
dataset.push_to_hub('dim/ru_turbo_alpaca_evol_instruct_3k')

# %%
from datasets import Dataset
Dataset.from_list(dataset.to_list()).push_to_hub('dim/ru_turbo_alpaca_evol_instruct_3k')
# Out:
# ...
# Pushing dataset shards to the dataset hub: 100%|██████████| 1/1 [00:02<00:00,  2.51s/it]
# ...

# %%
dataset[0]
# Out:
# {'instruction': 'Опиши происхождение и культурную значимость каждого вида кофе, включая регионы производства и традиционные способы приготовления.',
# ...
